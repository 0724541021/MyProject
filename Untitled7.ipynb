# %%
# Python equivalent
import numpy as np
x = np.array([1.2, 3.4, 2.5, 4.0, 5.1])
x.mean(), np.median(x), x.std(ddof=1), x.var(ddof=1)
# Out:
# (3.2399999999999998, 3.4, 1.4808781178746615, 2.193)

# %%
import pandas as pd
import numpy as np
df = pd.read_csv(
    r"C:\Users\Maingo Israel\OneDrive\Desktop\Masters Thesis\Top40_data_Analysis.csv",
    sep=";",                  # important for semicolon-separated values
    parse_dates=['Date']     # convert Date column to datetime
)
# Preview the first few rows
print(df.head())
# Out:
#         Date     Price      Open      High       Low
# 0 2011-01-31  28145.34  28232.10  28232.10  27873.19
# 1 2011-02-01  28625.33  28145.34  28634.73  28145.34
# 2 2011-02-02  29274.22  28625.33  29274.22  28625.33
# 3 2011-02-03  29609.47  29274.22  29609.47  29259.69
# 4 2011-02-04  29718.96  29609.47  29874.49  29609.47

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3516 entries, 0 to 3515
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3516 non-null   datetime64[ns]
#  1   Price   3516 non-null   float64
#  2   Open    3516 non-null   float64
#  3   High    3516 non-null   float64
#  4   Low     3516 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 137.5 KB

# %%
df.info()
df['Return'] = np.log(df['Price']).diff()*100
df[['Date','Price','Return']].head()
df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3516 entries, 0 to 3515
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    3516 non-null   datetime64[ns]
#  1   Price   3516 non-null   float64
#  2   Open    3516 non-null   float64
#  3   High    3516 non-null   float64
#  4   Low     3516 non-null   float64
# dtypes: datetime64[ns](1), float64(4)
# memory usage: 137.5 KB
#            Date     Price      Open      High       Low    Return
# 0    2011-01-31  28145.34  28232.10  28232.10  27873.19       NaN
# 1    2011-02-01  28625.33  28145.34  28634.73  28145.34  1.691019
# 2    2011-02-02  29274.22  28625.33  29274.22  28625.33  2.241528
# 3    2011-02-03  29609.47  29274.22  29609.47  29259.69  1.138698
# 4    2011-02-04  29718.96  29609.47  29874.49  29609.47  0.369098
# ...         ...       ...       ...       ...       ...       ...
# 3511 2025-02-19  80772.77  81413.51  81635.95  80772.77 -0.790133
# ...

# %%
df = df.iloc[1:]  # keeps all rows from index 1 onwards
#df = df.reset_index(drop=True)  # optional: reset index to start from 0
df
# Out:
#            Date     Price      Open      High       Low    Return
# 1    2011-02-01  28625.33  28145.34  28634.73  28145.34  1.691019
# 2    2011-02-02  29274.22  28625.33  29274.22  28625.33  2.241528
# 3    2011-02-03  29609.47  29274.22  29609.47  29259.69  1.138698
# 4    2011-02-04  29718.96  29609.47  29874.49  29609.47  0.369098
# 5    2011-02-07  29621.70  29718.96  29942.05  29621.70 -0.327803
# ...         ...       ...       ...       ...       ...       ...
# 3511 2025-02-19  80772.77  81413.51  81635.95  80772.77 -0.790133
# 3512 2025-02-20  81367.39  80772.77  81476.93  80497.21  0.733467
# 3513 2025-02-21  81391.76  81367.39  81667.92  81226.86  0.029946
# 3514 2025-02-24  79920.35  81391.76  81391.76  79920.35 -1.824353
# 3515 2025-02-25  80282.50  79920.35  80584.46  79521.10  0.452115
#
# [3515 rows x 6 columns]

# %%
import matplotlib.pyplot as plt
plt.figure()
plt.plot(df['Date'], df['Return'])
plt.title("Closing price plot over time")
plt.xlabel("Year")
plt.ylabel("Closing Price")
plt.show()

# %%
# Compute summary statistics
summary = df['Return'].describe()

# Round to 4 decimal places
summary_rounded = summary.round(5)

print(summary_rounded)
# Out:
# count    3515.00000
# mean        0.02982
# std         1.14137
# min       -10.45042
# 25%        -0.56997
# 50%         0.05201
# 75%         0.66839
# max         9.05698
# Name: Return, dtype: float64

# %%
# Skewness
skew = df['Return'].skew()

# Kurtosis
kurt = df['Return'].kurtosis()  # Fisher’s definition: normal = 0

print("Skewness:", round(skew, 5))
print("Kurtosis:", round(kurt, 5))
# Out:
# Skewness: -0.26731
# Kurtosis: 6.34424

# %%
import seaborn as sns

# --------------------------
# 2. Create figure with 4 plots
# --------------------------
fig, axs = plt.subplots(2, 2, figsize=(14,10))  # 2x2 grid

# --- Time series plot ---
axs[0,0].plot(df['Date'], df['Return'], color='blue')
axs[0,0].set_title("Time Series of Returns", fontsize=12)
axs[0,0].set_xlabel("Date")
axs[0,0].set_ylabel("Return (%)")

# --- Histogram with density line ---
sns.histplot(df['Return'], bins=50, kde=True, color='green', ax=axs[0,1])
axs[0,1].set_title("Histogram with Density", fontsize=12)
axs[0,1].set_xlabel("Return (%)")
axs[0,1].set_ylabel("Frequency")

# --- Density plot ---
sns.kdeplot(df['Return'], fill=True, color='orange', ax=axs[1,0])
axs[1,0].set_title("Density Plot", fontsize=12)
axs[1,0].set_xlabel("Return (%)")
axs[1,0].set_ylabel("Density")

# --- Box-Whisker plot ---
sns.boxplot(x=df['Return'], color='pink', ax=axs[1,1])
axs[1,1].set_title("Box-Whisker Plot", fontsize=12)
axs[1,1].set_xlabel("Return (%)")

# --------------------------
# 3. Adjust layout
# --------------------------
plt.tight_layout()
plt.show()
